# %% [markdown]
# # Lab | Simple LLM App with LCEL
#
# In this quickstart we'll show you how to build a simple LLM application with LangChain. This application will translate text from English into another language. This is a relatively simple LLM application - it's just a single LLM call plus some prompting. Still, this is a great way to get started with LangChain - a lot of features can be built with just some prompting and an LLM call!
#
# ### LangSmith
#
# Many of the applications you build with LangChain will contain multiple steps with multiple invocations of LLM calls.
# As these applications get more and more complex, it becomes crucial to be able to inspect what exactly is going on inside your chain or agent.
# The best way to do this is with [LangSmith](https://smith.langchain.com).
#
# After you sign up at the link above, make sure to set your environment variables to start logging traces:
#
# ```shell
# export LANGCHAIN_TRACING_V2="true"
# export LANGCHAIN_API_KEY="..."
# ```
#
# Or, if in a notebook, you can set them with:
#
# ```python
# import getpass
# import os
#
# os.environ["LANGCHAIN_TRACING_V2"] = "true"
# os.environ["LANGCHAIN_API_KEY"] = getpass.getpass()
# ```

# %%
# !pip install langchain-openai
# Out:
# Requirement already satisfied: langchain-openai in c:\users\phiph\anaconda3\lib\site-packages (1.2.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.3.2 in c:\users\phiph\anaconda3\lib\site-packages (from langchain-openai) (1.4.0)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in c:\users\phiph\anaconda3\lib\site-packages (from langchain-openai) (2.32.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\phiph\anaconda3\lib\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\phiph\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in c:\users\phiph\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\phiph\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.8.3)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\phiph\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\phiph\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\phiph\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\phiph\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (9.0.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\phiph\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\phiph\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\phiph\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.3.2->langchain-openai) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\phiph\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\phiph\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\phiph\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\phiph\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (2.33.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\phiph\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\phiph\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.24.0)
# Requirement already satisfied: anyio in c:\users\phiph\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (4.7.0)
# Requirement already satisfied: certifi in c:\users\phiph\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\phiph\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (1.0.9)
# Requirement already satisfied: idna in c:\users\phiph\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\phiph\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\phiph\anaconda3\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\phiph\anaconda3\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.14.0)
# Requirement already satisfied: sniffio in c:\users\phiph\anaconda3\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\phiph\anaconda3\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\phiph\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\phiph\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.3.2->langchain-openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\phiph\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\phiph\anaconda3\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\phiph\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\phiph\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (2.3.0)
# Requirement already satisfied: colorama in c:\users\phiph\anaconda3\lib\site-packages (from tqdm>4->openai<3.0.0,>=2.26.0->langchain-openai) (0.4.6)

# %%
# !pip install -U langsmith[openai-agents]
# Out:
# Requirement already satisfied: langsmith[openai-agents] in c:\users\phiph\anaconda3\lib\site-packages (0.8.3)
# Collecting langsmith[openai-agents]
#   Downloading langsmith-0.8.5-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\phiph\anaconda3\lib\site-packages (from langsmith[openai-agents]) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\phiph\anaconda3\lib\site-packages (from langsmith[openai-agents]) (3.11.9)
# Requirement already satisfied: packaging>=23.2 in c:\users\phiph\anaconda3\lib\site-packages (from langsmith[openai-agents]) (24.2)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\phiph\anaconda3\lib\site-packages (from langsmith[openai-agents]) (2.12.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\phiph\anaconda3\lib\site-packages (from langsmith[openai-agents]) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\phiph\anaconda3\lib\site-packages (from langsmith[openai-agents]) (2.33.1)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\phiph\anaconda3\lib\site-packages (from langsmith[openai-agents]) (0.14.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\phiph\anaconda3\lib\site-packages (from langsmith[openai-agents]) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\phiph\anaconda3\lib\site-packages (from langsmith[openai-agents]) (0.24.0)
# Collecting openai-agents>=0.0.3 (from langsmith[openai-agents])
#   Downloading openai_agents-0.17.3-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: anyio in c:\users\phiph\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith[openai-agents]) (4.7.0)
# Requirement already satisfied: certifi in c:\users\phiph\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith[openai-agents]) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\phiph\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith[openai-agents]) (1.0.9)
# Requirement already satisfied: idna in c:\users\phiph\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith[openai-agents]) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\phiph\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith[openai-agents]) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\phiph\anaconda3\lib\site-packages (from pydantic<3,>=2->langsmith[openai-agents]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\phiph\anaconda3\lib\site-packages (from pydantic<3,>=2->langsmith[openai-agents]) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\phiph\anaconda3\lib\site-packages (from pydantic<3,>=2->langsmith[openai-agents]) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\phiph\anaconda3\lib\site-packages (from pydantic<3,>=2->langsmith[openai-agents]) (0.4.2)
# Collecting griffelib<3,>=2 (from openai-agents>=0.0.3->langsmith[openai-agents])
#   Downloading griffelib-2.0.2-py3-none-any.whl.metadata (1.3 kB)
# Collecting mcp<2,>=1.19.0 (from openai-agents>=0.0.3->langsmith[openai-agents])
#   Downloading mcp-1.27.1-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: openai<3,>=2.26.0 in c:\users\phiph\anaconda3\lib\site-packages (from openai-agents>=0.0.3->langsmith[openai-agents]) (2.32.0)
# Collecting types-requests<3,>=2.0 (from openai-agents>=0.0.3->langsmith[openai-agents])
#   Downloading types_requests-2.33.0.20260518-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: websockets<17,>=15.0 in c:\users\phiph\anaconda3\lib\site-packages (from openai-agents>=0.0.3->langsmith[openai-agents]) (16.0)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\phiph\anaconda3\lib\site-packages (from mcp<2,>=1.19.0->openai-agents>=0.0.3->langsmith[openai-agents]) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\users\phiph\anaconda3\lib\site-packages (from mcp<2,>=1.19.0->openai-agents>=0.0.3->langsmith[openai-agents]) (4.23.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in c:\users\phiph\anaconda3\lib\site-packages (from mcp<2,>=1.19.0->openai-agents>=0.0.3->langsmith[openai-agents]) (2.14.1)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\users\phiph\anaconda3\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.19.0->openai-agents>=0.0.3->langsmith[openai-agents]) (2.10.1)
# Collecting python-multipart>=0.0.9 (from mcp<2,>=1.19.0->openai-agents>=0.0.3->langsmith[openai-agents])
#   Downloading python_multipart-0.0.29-py3-none-any.whl.metadata (2.1 kB)
# Collecting pywin32>=310 (from mcp<2,>=1.19.0->openai-agents>=0.0.3->langsmith[openai-agents])
#   Downloading pywin32-311-cp313-cp313-win_amd64.whl.metadata (10 kB)
# Collecting sse-starlette>=1.6.1 (from mcp<2,>=1.19.0->openai-agents>=0.0.3->langsmith[openai-agents])
#   Downloading sse_starlette-3.4.4-py3-none-any.whl.metadata (15 kB)
# Collecting starlette>=0.27 (from mcp<2,>=1.19.0->openai-agents>=0.0.3->langsmith[openai-agents])
#   Downloading starlette-1.0.1-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: uvicorn>=0.31.1 in c:\users\phiph\anaconda3\lib\site-packages (from mcp<2,>=1.19.0->openai-agents>=0.0.3->langsmith[openai-agents]) (0.46.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\phiph\anaconda3\lib\site-packages (from openai<3,>=2.26.0->openai-agents>=0.0.3->langsmith[openai-agents]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\phiph\anaconda3\lib\site-packages (from openai<3,>=2.26.0->openai-agents>=0.0.3->langsmith[openai-agents]) (0.14.0)
# Requirement already satisfied: sniffio in c:\users\phiph\anaconda3\lib\site-packages (from openai<3,>=2.26.0->openai-agents>=0.0.3->langsmith[openai-agents]) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\phiph\anaconda3\lib\site-packages (from openai<3,>=2.26.0->openai-agents>=0.0.3->langsmith[openai-agents]) (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\phiph\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith[openai-agents]) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\phiph\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith[openai-agents]) (2.3.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\phiph\anaconda3\lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.19.0->openai-agents>=0.0.3->langsmith[openai-agents]) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\phiph\anaconda3\lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.19.0->openai-agents>=0.0.3->langsmith[openai-agents]) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\phiph\anaconda3\lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.19.0->openai-agents>=0.0.3->langsmith[openai-agents]) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\phiph\anaconda3\lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.19.0->openai-agents>=0.0.3->langsmith[openai-agents]) (0.22.3)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\phiph\anaconda3\lib\site-packages (from pydantic-settings>=2.5.2->mcp<2,>=1.19.0->openai-agents>=0.0.3->langsmith[openai-agents]) (1.1.0)
# Requirement already satisfied: cryptography>=3.4.0 in c:\users\phiph\anaconda3\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.19.0->openai-agents>=0.0.3->langsmith[openai-agents]) (44.0.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\phiph\anaconda3\lib\site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2,>=1.19.0->openai-agents>=0.0.3->langsmith[openai-agents]) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\phiph\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2,>=1.19.0->openai-agents>=0.0.3->langsmith[openai-agents]) (2.21)
# Requirement already satisfied: colorama in c:\users\phiph\anaconda3\lib\site-packages (from tqdm>4->openai<3,>=2.26.0->openai-agents>=0.0.3->langsmith[openai-agents]) (0.4.6)
# Requirement already satisfied: click>=7.0 in c:\users\phiph\anaconda3\lib\site-packages (from uvicorn>=0.31.1->mcp<2,>=1.19.0->openai-agents>=0.0.3->langsmith[openai-agents]) (8.1.8)
# Downloading langsmith-0.8.5-py3-none-any.whl (399 kB)
# Downloading openai_agents-0.17.3-py3-none-any.whl (841 kB)
#    ---------------------------------------- 0.0/841.5 kB ? eta -:--:--
#    --------------------------------------- 841.5/841.5 kB 12.0 MB/s eta 0:00:00
# Downloading griffelib-2.0.2-py3-none-any.whl (142 kB)
# Downloading mcp-1.27.1-py3-none-any.whl (216 kB)
# Downloading types_requests-2.33.0.20260518-py3-none-any.whl (21 kB)
# Downloading python_multipart-0.0.29-py3-none-any.whl (29 kB)
# Downloading pywin32-311-cp313-cp313-win_amd64.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ------------ --------------------------- 2.9/9.5 MB 14.4 MB/s eta 0:00:01
#    ------------------------ --------------- 5.8/9.5 MB 14.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.4/9.5 MB 13.6 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 13.0 MB/s eta 0:00:00
# Downloading sse_starlette-3.4.4-py3-none-any.whl (16 kB)
# Downloading starlette-1.0.1-py3-none-any.whl (72 kB)
# Installing collected packages: pywin32, types-requests, python-multipart, griffelib, starlette, sse-starlette, langsmith, mcp, openai-agents
#
#   Attempting uninstall: pywin32
#
#     Found existing installation: pywin32 308
#
#     Uninstalling pywin32-308:
#
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#       Successfully uninstalled pywin32-308
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---------------------------------------- 0/9 [pywin32]
#    ---- ----------------------------------- 1/9 [types-requests]
#    ------------- -------------------------- 3/9 [griffelib]
#    ------------- -------------------------- 3/9 [griffelib]
#    ------------- -------------------------- 3/9 [griffelib]
#    ------------- -------------------------- 3/9 [griffelib]
#    ----------------- ---------------------- 4/9 [starlette]
#    ----------------- ---------------------- 4/9 [starlette]
#    ----------------- ---------------------- 4/9 [starlette]
#   Attempting uninstall: langsmith
#    ----------------- ---------------------- 4/9 [starlette]
#    -------------------------- ------------- 6/9 [langsmith]
#     Found existing installation: langsmith 0.8.3
#    -------------------------- ------------- 6/9 [langsmith]
#     Uninstalling langsmith-0.8.3:
#    -------------------------- ------------- 6/9 [langsmith]
#       Successfully uninstalled langsmith-0.8.3
#    -------------------------- ------------- 6/9 [langsmith]
#    -------------------------- ------------- 6/9 [langsmith]
#    -------------------------- ------------- 6/9 [langsmith]
#    -------------------------- ------------- 6/9 [langsmith]
#    -------------------------- ------------- 6/9 [langsmith]
#    -------------------------- ------------- 6/9 [langsmith]
#    -------------------------- ------------- 6/9 [langsmith]
#    -------------------------- ------------- 6/9 [langsmith]
#    ------------------------------- -------- 7/9 [mcp]
#    ------------------------------- -------- 7/9 [mcp]
#    ------------------------------- -------- 7/9 [mcp]
#    ------------------------------- -------- 7/9 [mcp]
#    ------------------------------- -------- 7/9 [mcp]
#    ------------------------------- -------- 7/9 [mcp]
#    ------------------------------- -------- 7/9 [mcp]
#    ------------------------------- -------- 7/9 [mcp]
#    ----------------------------------- ---- 8/9 [openai-agents]
#    ----------------------------------- ---- 8/9 [openai-agents]
#    ----------------------------------- ---- 8/9 [openai-agents]
#    ----------------------------------- ---- 8/9 [openai-agents]
#    ----------------------------------- ---- 8/9 [openai-agents]
#    ----------------------------------- ---- 8/9 [openai-agents]
#    ----------------------------------- ---- 8/9 [openai-agents]
#    ----------------------------------- ---- 8/9 [openai-agents]
#    ----------------------------------- ---- 8/9 [openai-agents]
#    ----------------------------------- ---- 8/9 [openai-agents]
#    ----------------------------------- ---- 8/9 [openai-agents]
#    ----------------------------------- ---- 8/9 [openai-agents]
#    ----------------------------------- ---- 8/9 [openai-agents]
#    ----------------------------------- ---- 8/9 [openai-agents]
#    ----------------------------------- ---- 8/9 [openai-agents]
#    ----------------------------------- ---- 8/9 [openai-agents]
#    ----------------------------------- ---- 8/9 [openai-agents]
#    ----------------------------------- ---- 8/9 [openai-agents]
#    ----------------------------------- ---- 8/9 [openai-agents]
#    ----------------------------------- ---- 8/9 [openai-agents]
#    ----------------------------------- ---- 8/9 [openai-agents]
#    ---------------------------------------- 9/9 [openai-agents]
#
# Successfully installed griffelib-2.0.2 langsmith-0.8.5 mcp-1.27.1 openai-agents-0.17.3 python-multipart-0.0.29 pywin32-311 sse-starlette-3.4.4 starlette-1.0.1 types-requests-2.33.0.20260518

# %%
import getpass
import os

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_ENDPOINT"] = "https://eu.api.smith.langchain.com"
os.environ["LANGCHAIN_API_KEY"] = os.getenv('LANGCHAIN_API_KEY')
os.environ["LANGCHAIN_PROJECT"] = "ironhack-labs"
os.environ["OPENAI_API_KEY"] = os.getenv('OPENAI_API_KEY') # Set OPENAI_API_KEY here

# %%
# | output: false
# | echo: false

from langchain_openai import ChatOpenAI

model = ChatOpenAI(model="gpt-3.5-turbo")

# %% [markdown]
# Let's first use the model directly. `ChatModel`s are instances of LangChain "Runnables", which means they expose a standard interface for interacting with them. To just simply call the model, we can pass in a list of messages to the `.invoke` method.

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage(content="Translate the following from French into English"), #Feel free to try something else here
    HumanMessage(content="C'est un animal de petite taille, notamment caractérisé par ses oreilles triangulaires et pointues, ses yeux ronds et brillants, son museau court et arrondi, ainsi que son poil doux et soyeux."),
]

model.invoke(messages)
# Out:
# AIMessage(content='It is a small animal, notably characterized by its triangular and pointed ears, round and shiny eyes, short and rounded muzzle, as well as its soft and silky fur.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 34, 'prompt_tokens': 71, 'total_tokens': 105, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DiNj1Bf5wIrVOXmM63j8YBbiGpGos', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e50ad-6a7d-7180-9e08-86e3d62587ed-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 71, 'output_tokens': 34, 'total_tokens': 105, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# If we've enable LangSmith, we can see that this run is logged to LangSmith, and can see the [LangSmith trace](https://smith.langchain.com/public/88baa0b2-7c1a-4d09-ba30-a47985dde2ea/r)

# %% [markdown]
# ## OutputParsers
#
# Notice that the response from the model is an `AIMessage`. This contains a string response along with other metadata about the response. Oftentimes we may just want to work with the string response. We can parse out just this response by using a simple output parser.
#
# We first import the simple output parser.

# %%
from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()

# %% [markdown]
# One way to use it is to use it by itself. For example, we could save the result of the language model call and then pass it to the parser.

# %%
result = model.invoke(messages)

# %%
parser.invoke(result)
# Out:
# 'It is a small animal, notably characterized by its triangular and pointed ears, round and shiny eyes, short and rounded muzzle, as well as its soft and silky fur.'

# %% [markdown]
# More commonly, we can "chain" the model with this output parser. This means this output parser will get called everytime in this chain. This chain takes on the input type of the language model (string or list of message) and returns the output type of the output parser (string).
#
# We can easily create the chain using the `|` operator. The `|` operator is used in LangChain to combine two elements together.

# %%
chain = model | parser

# %%
chain.invoke(messages)
# Out:
# 'It is a small-sized animal, notably characterized by its triangular and pointed ears, its round and shiny eyes, its short and rounded snout, as well as its soft and silky fur.'

# %% [markdown]
# If we now look at LangSmith, we can see that the chain has two steps: first the language model is called, then the result of that is passed to the output parser. We can see the [LangSmith trace]( https://smith.langchain.com/public/f1bdf656-2739-42f7-ac7f-0f1dd712322f/r)

# %% [markdown]
# ## Prompt Templates
#
# Right now we are passing a list of messages directly into the language model. Where does this list of messages come from? Usually, it is constructed from a combination of user input and application logic. This application logic usually takes the raw user input and transforms it into a list of messages ready to pass to the language model. Common transformations include adding a system message or formatting a template with the user input.
#
# PromptTemplates are a concept in LangChain designed to assist with this transformation. They take in raw user input and return data (a prompt) that is ready to pass into a language model.
#
# Let's create a PromptTemplate here. It will take in two user variables:
#
# - `language`: The language to translate text into
# - `text`: The text to translate

# %%
from langchain_core.prompts import ChatPromptTemplate

# %% [markdown]
# First, let's create a string that we will format to be the system message:

# %%
system_template = "Translate the following into {language}:"

# %% [markdown]
# Next, we can create the PromptTemplate. This will be a combination of the `system_template` as well as a simpler template for where the put the text

# %%
prompt_template = ChatPromptTemplate.from_messages(
    [("system", system_template), ("user", "{text}")]
)

# %% [markdown]
# The input to this prompt template is a dictionary. We can play around with this prompt template by itself to see what it does by itself

# %%
result = prompt_template.invoke({"language": "italian", "text": "Hello, how are you today?"})

result
# Out:
# ChatPromptValue(messages=[SystemMessage(content='Translate the following into italian:', additional_kwargs={}, response_metadata={}), HumanMessage(content='Hello, how are you today?', additional_kwargs={}, response_metadata={})])

# %% [markdown]
# We can see that it returns a `ChatPromptValue` that consists of two messages. If we want to access the messages directly we do:

# %%
result.to_messages()
# Out:
# [SystemMessage(content='Translate the following into italian:', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='Hello, how are you today?', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# ## Chaining together components with LCEL
#
# We can now combine this with the model and the output parser from above using the pipe (`|`) operator:

# %%
chain = prompt_template | model | parser

# %%
chain.invoke({"language": "italian", "text": "This is a simple LLM application built with LangChain"})
# Out:
# 'Questa è una semplice applicazione LLM costruita con LangChain.'

# %% [markdown]
# This is a simple example of using [LangChain Expression Language (LCEL)](/docs/concepts/#langchain-expression-language-lcel) to chain together LangChain modules. There are several benefits to this approach, including optimized streaming and tracing support.
#
# If we take a look at the LangSmith trace, we can see all three components show up in the [LangSmith trace](https://smith.langchain.com/public/bc49bec0-6b13-4726-967f-dbd3448b786d/r).

# %% [markdown]
# ## Serving with LangServe
#
# Now that we've built an application, we need to serve it. That's where LangServe comes in.
# LangServe helps developers deploy LangChain chains as a REST API. You do not need to use LangServe to use LangChain, but in this guide we'll show how you can deploy your app with LangServe.
#
# While the first part of this guide was intended to be run in a Jupyter Notebook or script, we will now move out of that. We will be creating a Python file and then interacting with it from the command line.
#
# Install with:
# ```bash
# pip install "langserve[all]"
# ```
#
# ### Server
#
# To create a server for our application we'll make a `serve.py` file. This will contain our logic for serving our application. It consists of three things:
# 1. The definition of our chain that we just built above
# 2. Our FastAPI app
# 3. A definition of a route from which to serve the chain, which is done with `langserve.add_routes`
#
#
# ```python
# #!/usr/bin/env python
# from typing import List
#
# from fastapi import FastAPI
# from langchain_core.prompts import ChatPromptTemplate
# from langchain_core.output_parsers import StrOutputParser
# from langchain_openai import ChatOpenAI
# from langserve import add_routes
#
# # 1. Create prompt template
# system_template = "Translate the following into {language}:"
# prompt_template = ChatPromptTemplate.from_messages([
#     ('system', system_template),
#     ('user', '{text}')
# ])
#
# # 2. Create model
# model = ChatOpenAI()
#
# # 3. Create parser
# parser = StrOutputParser()
#
# # 4. Create chain
# chain = prompt_template | model | parser
#
#
# # 4. App definition
# app = FastAPI(
#   title="LangChain Server",
#   version="1.0",
#   description="A simple API server using LangChain's Runnable interfaces",
# )
#
# # 5. Adding chain route
#
# add_routes(
#     app,
#     chain,
#     path="/chain",
# )
#
# if __name__ == "__main__":
#     import uvicorn
#
#     uvicorn.run(app, host="localhost", port=8000)
# ```
#
# And that's it! If we execute this file:
# ```bash
# python serve.py
# ```
# we should see our chain being served at [http://localhost:8000](http://localhost:8000).
#
# ### Playground
#
# Every LangServe service comes with a simple [built-in UI](https://github.com/langchain-ai/langserve/blob/main/README.md#playground) for configuring and invoking the application with streaming output and visibility into intermediate steps.
# Head to [http://localhost:8000/chain/playground/](http://localhost:8000/chain/playground/) to try it out! Pass in the same inputs as before - `{"language": "italian", "text": "hi"}` - and it should respond same as before.
#
# ### Client
#
# Now let's set up a client for programmatically interacting with our service. We can easily do this with the `[langserve.RemoteRunnable](/docs/langserve/#client)`.
# Using this, we can interact with the served chain as if it were running client-side.

# %%
# !pip install langserve[all]
# Out:
# Collecting langserve[all]
#   Downloading langserve-0.3.3-py3-none-any.whl.metadata (40 kB)
# Collecting fastapi<1,>=0.90.1 (from langserve[all])
#   Downloading fastapi-0.136.1-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: httpx<1.0,>=0.23.0 in c:\users\phiph\anaconda3\lib\site-packages (from langserve[all]) (0.28.1)
# Requirement already satisfied: langchain-core<2,>=0.3 in c:\users\phiph\anaconda3\lib\site-packages (from langserve[all]) (1.4.0)
# Requirement already satisfied: orjson<4,>=2 in c:\users\phiph\anaconda3\lib\site-packages (from langserve[all]) (3.11.9)
# Requirement already satisfied: pydantic<3.0,>=2.7 in c:\users\phiph\anaconda3\lib\site-packages (from langserve[all]) (2.12.5)
# Collecting sse-starlette<2.0.0,>=1.3.0 (from langserve[all])
#   Downloading sse_starlette-1.8.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: starlette>=0.46.0 in c:\users\phiph\anaconda3\lib\site-packages (from fastapi<1,>=0.90.1->langserve[all]) (1.0.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\phiph\anaconda3\lib\site-packages (from fastapi<1,>=0.90.1->langserve[all]) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\phiph\anaconda3\lib\site-packages (from fastapi<1,>=0.90.1->langserve[all]) (0.4.2)
# Collecting annotated-doc>=0.0.2 (from fastapi<1,>=0.90.1->langserve[all])
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: anyio in c:\users\phiph\anaconda3\lib\site-packages (from httpx<1.0,>=0.23.0->langserve[all]) (4.7.0)
# Requirement already satisfied: certifi in c:\users\phiph\anaconda3\lib\site-packages (from httpx<1.0,>=0.23.0->langserve[all]) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\phiph\anaconda3\lib\site-packages (from httpx<1.0,>=0.23.0->langserve[all]) (1.0.9)
# Requirement already satisfied: idna in c:\users\phiph\anaconda3\lib\site-packages (from httpx<1.0,>=0.23.0->langserve[all]) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\phiph\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.23.0->langserve[all]) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\phiph\anaconda3\lib\site-packages (from langchain-core<2,>=0.3->langserve[all]) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in c:\users\phiph\anaconda3\lib\site-packages (from langchain-core<2,>=0.3->langserve[all]) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\phiph\anaconda3\lib\site-packages (from langchain-core<2,>=0.3->langserve[all]) (0.8.5)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\phiph\anaconda3\lib\site-packages (from langchain-core<2,>=0.3->langserve[all]) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\phiph\anaconda3\lib\site-packages (from langchain-core<2,>=0.3->langserve[all]) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\phiph\anaconda3\lib\site-packages (from langchain-core<2,>=0.3->langserve[all]) (9.0.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\phiph\anaconda3\lib\site-packages (from langchain-core<2,>=0.3->langserve[all]) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\phiph\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2,>=0.3->langserve[all]) (2.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\phiph\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3->langserve[all]) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\phiph\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3->langserve[all]) (2.33.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\phiph\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3->langserve[all]) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\phiph\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3->langserve[all]) (0.24.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\phiph\anaconda3\lib\site-packages (from pydantic<3.0,>=2.7->langserve[all]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\phiph\anaconda3\lib\site-packages (from pydantic<3.0,>=2.7->langserve[all]) (2.41.5)
# Requirement already satisfied: uvicorn in c:\users\phiph\anaconda3\lib\site-packages (from sse-starlette<2.0.0,>=1.3.0->langserve[all]) (0.46.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\phiph\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3->langserve[all]) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\phiph\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3->langserve[all]) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\phiph\anaconda3\lib\site-packages (from anyio->httpx<1.0,>=0.23.0->langserve[all]) (1.3.0)
# Requirement already satisfied: click>=7.0 in c:\users\phiph\anaconda3\lib\site-packages (from uvicorn->sse-starlette<2.0.0,>=1.3.0->langserve[all]) (8.1.8)
# Requirement already satisfied: colorama in c:\users\phiph\anaconda3\lib\site-packages (from click>=7.0->uvicorn->sse-starlette<2.0.0,>=1.3.0->langserve[all]) (0.4.6)
# Downloading langserve-0.3.3-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 9.5 MB/s eta 0:00:00
# Downloading fastapi-0.136.1-py3-none-any.whl (117 kB)
# Downloading sse_starlette-1.8.2-py3-none-any.whl (8.9 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Installing collected packages: annotated-doc, fastapi, sse-starlette, langserve
#
#    ---------- ----------------------------- 1/4 [fastapi]
#   Attempting uninstall: sse-starlette
#    ---------- ----------------------------- 1/4 [fastapi]
#    -------------------- ------------------- 2/4 [sse-starlette]
#     Found existing installation: sse-starlette 3.4.4
#    -------------------- ------------------- 2/4 [sse-starlette]
#     Uninstalling sse-starlette-3.4.4:
#    -------------------- ------------------- 2/4 [sse-starlette]
#       Successfully uninstalled sse-starlette-3.4.4
#    -------------------- ------------------- 2/4 [sse-starlette]
#    ------------------------------ --------- 3/4 [langserve]
#    ---------------------------------------- 4/4 [langserve]
#
# Successfully installed annotated-doc-0.0.4 fastapi-0.136.1 langserve-0.3.3 sse-starlette-1.8.2

# %%
from langserve import RemoteRunnable

remote_chain = RemoteRunnable("http://localhost:8000/chain/")
remote_chain.invoke({"language": "italian", "text": None})

# %% [markdown]
# To learn more about the many other features of LangServe [head here](/docs/langserve).

# %% [markdown]
# ## Conclusion
#
# That's it! In this tutorial you've learned how to create your first simple LLM application. You've learned how to work with language models, how to parse their outputs, how to create a prompt template, chaining them with LCEL, how to get great observability into chains you create with LangSmith, and how to deploy them with LangServe.
#
# This just scratches the surface of what you will want to learn to become a proficient AI Engineer. Luckily - we've got a lot of other resources!
#
# For further reading on the core concepts of LangChain, we've got detailed [Conceptual Guides](/docs/concepts).
#
# If you have more specific questions on these concepts, check out the following sections of the how-to guides:
#
# - [LangChain Expression Language (LCEL)](/docs/how_to/#langchain-expression-language-lcel)
# - [Prompt templates](/docs/how_to/#prompt-templates)
# - [Chat models](/docs/how_to/#chat-models)
# - [Output parsers](/docs/how_to/#output-parsers)
# - [LangServe](/docs/langserve/)
#
# And the LangSmith docs:
#
# - [LangSmith](https://docs.smith.langchain.com)
